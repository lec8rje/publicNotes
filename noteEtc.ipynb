# %% [markdown]
# This will act as a notebook to point people to if I need to show plots or code snippets.

# %% [markdown]
# This is just a quick plot in python to prove this works using https://jupyter.org/ notebooks.

# %%
import numpy as np
import matplotlib.pyplot as plt
nx = 10
ny = 5
arr = np.arange( nx * ny).reshape(( ny, nx))
plt.imshow(arr)
plt.show()
